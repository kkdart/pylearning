# %%
import pandas as pd
website_data = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_population')
#check and see how many talbes pandas finds
len(website_data)
# Out:
# 5

# %%
#Iterate through the tables to find the "Right" table

# for i in website_data:
#     print(i.head())
# website_data[0].head

state_pop = website_data[0]
state_pop.head
# Out:
#   Rank      State or territory Census population[8][a]                \
#   2022 2020 State or territory     July 1, 2022 (est.) April 1, 2020
# 0  1.0  1.0         California              39029342.0      39538223
# 1  2.0  2.0              Texas              30029572.0      29145505
# 2  3.0  3.0            Florida              22244823.0      21538187
# 3  4.0  4.0           New York              19677151.0      20201249
# 4  5.0  5.0       Pennsylvania              12972008.0      13002700
#
#                 Change, 2010–2020[8][a]           \
#   April 1, 2010                       %     Abs.
# 0      37253956                   6.13%  2284267
# 1      25145561                  15.91%  3999944
# 2      18801310                  14.56%  2736877
# 3      19378102                   4.25%   823147
# 4      12702379                   2.36%   300321
#
#   House of Reps. from the 2022 elections          \
#                                    Seats       %
# ...

# %%
#Change from multi header to single header
state_pop.columns = [f'{i} {j}' for i, j in state_pop.columns]
state_pop.dropna(inplace=True)
state_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 16 columns):
#  #   Column                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                     --------------  -----
#  0   Rank 2022                                                                                                  52 non-null     float64
#  1   Rank 2020                                                                                                  52 non-null     float64
#  2   State or territory State or territory                                                                      52 non-null     object
#  3   Census population[8][a] July 1, 2022 (est.)                                                                52 non-null     float64
# ...

# %%
state_pop.head()
# state_pop['Rank 2020'].min()

max_pop = state_pop['Census population[8][a] July 1, 2022 (est.)'].max()
f"{max_pop:,}"


series = pd.Series()
# Out:
# '39,029,342.0'

# %%
series = pd.Series()
print(series)
# Out:
# Series([], dtype: float64)
# /var/folders/2w/0cx_bnzn64sbtw5b8sfc7n840000gn/T/ipykernel_1895/1218685951.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series = pd.Series()
